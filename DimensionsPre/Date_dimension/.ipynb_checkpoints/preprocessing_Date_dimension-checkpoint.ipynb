# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

dataPath = "../../Data/"

# %%
Date_dimension = pd.read_csv(dataPath+"calendar.csv")

# %%
Date_dimension = Date_dimension[Date_dimension["year"]>2019]

# %%
# process?
Date_dimension["date"] = pd.to_datetime(Date_dimension["date"]).dt.strftime('%Y-%m-%d')

# %%
Date_dimension.head()
# Out:
#        sasdate  date_key        word_date        date  year  quarter  month  \
# 21914    21915     10120  January 1, 2020  2020-01-01  2020        1      1
# 21915    21916     10220  January 2, 2020  2020-01-02  2020        1      1
# 21916    21917     10320  January 3, 2020  2020-01-03  2020        1      1
# 21917    21918     10420  January 4, 2020  2020-01-04  2020        1      1
# 21918    21919     10520  January 5, 2020  2020-01-05  2020        1      1
#
#        day_of_month  week day_of_week  weekday month_and_year  holiday  \
# 21914             1     0         Wed        4        JAN1960  NEWYEAR
# 21915             2     0         Thu        5        JAN1960      NaN
# 21916             3     0         Fri        6        JAN1960      NaN
# 21917             4     0         Sat        7        JAN1960      NaN
# 21918             5     1         Sun        1        JAN1960      NaN
#
#       timezone_id   timezone  timezone_offset
# ...

# %%
Date_dimension.insert(0, "surrogate_key",  np.arange(len(Date_dimension)))
Date_dimension.to_csv("Date_dimension.csv",index=False)

# %%
# Date_dimension = Date_dimension.drop(columns=['date_key'])
# Date_dimension = Date_dimension.rename(columns={'date':'A'})
Date_dimension.head()
# Out:
#        surrogate_key  sasdate        word_date        date  year  quarter  \
# 21914              0    21915  January 1, 2020  2020-01-01  2020        1
# 21915              1    21916  January 2, 2020  2020-01-02  2020        1
# 21916              2    21917  January 3, 2020  2020-01-03  2020        1
# 21917              3    21918  January 4, 2020  2020-01-04  2020        1
# 21918              4    21919  January 5, 2020  2020-01-05  2020        1
#
#        month  day_of_month  week day_of_week  weekday month_and_year  holiday  \
# 21914      1             1     0         Wed        4        JAN1960  NEWYEAR
# 21915      1             2     0         Thu        5        JAN1960      NaN
# 21916      1             3     0         Fri        6        JAN1960      NaN
# 21917      1             4     0         Sat        7        JAN1960      NaN
# 21918      1             5     1         Sun        1        JAN1960      NaN
#
#       timezone_id   timezone  timezone_offset
# ...

# %%
Date_dimension

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql://yzhao156Uottawa82211099@www.eecs.uottawa.ca:15432/COVID-19")
# Out:
# ------------------------------------------------------------
# ModuleNotFoundError        Traceback (most recent call last)
# <ipython-input-38-bfaabd7857a7> in <module>
# ----> 1 engine = create_engine("postgresql://yzhao156Uottawa82211099@www.eecs.uottawa.ca:15432/COVID-19")
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     477     strategy = kwargs.pop("strategy", default_strategy)
#     478     strategy = strategies.strategies[strategy]
# --> 479     return strategy.create(*args, **kwargs)
#     480
#     481
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      85                 if k in kwargs:
#      86                     dbapi_args[k] = pop_kwarg(k)
# ---> 87             dbapi = dialect_cls.dbapi(**dbapi_args)
#      88
#      89         dialect_args["dbapi"] = dbapi
#
# ...

# %%
Good afternoon everyone,

I wanted to let you know that your group databases have been created. You have to follow the steps below in order to connect to your database.

Username: the part of your uOttawa ID before the @. Example abcde012

Group: your group number; e,g, group_0

Password: Your uOttawa password

In order to connect to the instance, you have to write the command below on the command line (the example below is for user abcde012 who is a member of group 23).

psql -h www.eecs.uottawa.ca -p 15432 -d group_23 -U abcde012

I will also discuss this on Friday. Please let me know if you have any questions. 

Best regards,

Parsa
