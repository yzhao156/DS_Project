# %%
import pandas as pd
import numpy as np

from datetime import datetime, timedelta

dataPath = "../../Data/"

# %%
Ottawa_Weather = pd.read_csv(dataPath+"DailyWeather/OttawaIntAirport.csv")
York_Weather = pd.read_csv(dataPath+"DailyWeather/NorthYork.csv")
Peel_Weather = pd.read_csv(dataPath+"DailyWeather/CapePeelWest.csv")
Durham, Halton = ("TO","DO")
frames = [Ottawa_Weather, York_Weather, Peel_Weather]
Weather_dimension = pd.concat(frames)

# %%
# Weather_dimension = Weather_dimension[['Longitude (x)', 'Latitude (y)', 'Station Name', 'Climate ID', 'Date/Time',
#        'PROVINCE_CODE', 'LOCAL_YEAR', 'LOCAL_MONTH', 'LOCAL_DAY','MEAN_TEMPERATURE',  'MIN_TEMPERATURE',
#        'MAX_TEMPERATURE', 
#        'TOTAL_PRECIPITATION',  'TOTAL_RAIN',
#         'TOTAL_SNOW', 'DIRECTION_MAX_GUST', 
#        'SPEED_MAX_GUST', 'COOLING_DEGREE_DAYS',
#       'HEATING_DEGREE_DAYS']]
Weather_dimension = Weather_dimension[["Longitude (x)","Latitude (y)","Station Name","Climate ID","Date/Time",
        "Year","Month","Day","Max Temp (°C)","Min Temp (°C)",
 "Mean Temp (°C)","Heat Deg Days (°C)","Cool Deg Days (°C)","Total Rain (mm)","Total Snow (cm)",
 "Total Precip (mm)"]]

Weather_dimension.insert(0, "surrogate_key",  np.arange(len(Weather_dimension)))
# Weather_dimension = Weather_dimension.dropna() TODO
# Weather_dimension["Date/Time"] = pd.to_datetime(Weather_dimension["Date/Time"] ).dt.strftime('%Y-%m-%d')

# %%
Weather_dimension.to_csv("Weather_dimension.csv",index=False)
Weather_dimension.head()
# Out:
#    surrogate_key  Longitude (x)  Latitude (y)   Station Name Climate ID  \
# 0              0         -75.67         45.32  OTTAWA INTL A    6106001
# 1              1         -75.67         45.32  OTTAWA INTL A    6106001
# 2              2         -75.67         45.32  OTTAWA INTL A    6106001
# 3              3         -75.67         45.32  OTTAWA INTL A    6106001
# 4              4         -75.67         45.32  OTTAWA INTL A    6106001
#
#     Date/Time  Year  Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0  2020-01-01  2020      1    1            1.1           -2.0            -0.5
# 1  2020-01-02  2020      1    2            4.4           -4.6            -0.1
# 2  2020-01-03  2020      1    3            4.7            1.2             3.0
# 3  2020-01-04  2020      1    4            1.4           -3.0            -0.8
# 4  2020-01-05  2020      1    5           -3.0          -12.9            -8.0
#
#    Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  Total Snow (cm)  \
# 0                18.5                 0.0              0.0              0.0
# 1                18.1                 0.0              0.0              0.0
# 2                15.0                 0.0              0.0              0.0
# 3                18.8                 0.0              0.0              1.8
# 4                26.0                 0.0              0.0              0.0
#
#    Total Precip (mm)
# 0                0.0
# 1                0.0
# 2                0.0
# 3                1.3
# 4                0.0
