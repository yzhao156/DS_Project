# %%
import pandas as pd
import numpy as np

from datetime import datetime, timedelta

# %%
Ottawa_Weather = pd.read_csv("../../Data/DailyWeather/OttawaIntAirport.csv")
York_Weather = pd.read_csv("../../Data/DailyWeather/NorthYork.csv")
Peel_Weather = pd.read_csv("../../Data/DailyWeather/CapePeelWest.csv")
Durham, Halton = ("TO","DO")

# %%
(Peel_Weather+York_Weather).head()
# Out:
#    Longitude (x)  Latitude (y)    Station Name  Climate ID   Date/Time  Year  \
# 0        -107.82         69.04  CAPE PEEL WEST     2400697  2020-01-01  2020
# 1        -107.82         69.04  CAPE PEEL WEST     2400697  2020-01-02  2020
# 2        -107.82         69.04  CAPE PEEL WEST     2400697  2020-01-03  2020
# 3        -107.82         69.04  CAPE PEEL WEST     2400697  2020-01-04  2020
# 4        -107.82         69.04  CAPE PEEL WEST     2400697  2020-01-05  2020
#
#    Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# 0      1    1           NaN          -24.0  ...             NaN
# 1      1    2           NaN          -21.9  ...             NaN
# 2      1    3           NaN          -34.2  ...             NaN
# 3      1    4           NaN          -29.6  ...             NaN
# 4      1    5           NaN          -29.8  ...             NaN
#
#    Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# ...

# %%
Weather_dimension
