# %%
import pandas as pd
import numpy as np

from datetime import datetime, timedelta

cases = pd.read_csv("../../Data/2020_CA_Region_Mobility_Report.csv")
cases = cases[(cases["sub_region_1"]=="Ontario")]
# cases = cases[cases["sub_region_2"]==("Toronto Division" or "Ottawa Division")]

# %%
cases[["country_region","sub_region_1","sub_region_2"]].drop_duplicates()
# Out:
#       country_region sub_region_1  \
# 35916         Canada      Ontario
# 36298         Canada      Ontario
# 36680         Canada      Ontario
# 37056         Canada      Ontario
# 37438         Canada      Ontario
# 37813         Canada      Ontario
# 38194         Canada      Ontario
# 38570         Canada      Ontario
# 38946         Canada      Ontario
# 39325         Canada      Ontario
# 39707         Canada      Ontario
# 40089         Canada      Ontario
# 40471         Canada      Ontario
# 40850         Canada      Ontario
# 41226         Canada      Ontario
# 41490         Canada      Ontario
# 41872         Canada      Ontario
# 42254         Canada      Ontario
# 42629         Canada      Ontario
# 43005         Canada      Ontario
# 43380         Canada      Ontario
# 43762         Canada      Ontario
# 44138         Canada      Ontario
# 44517         Canada      Ontario
# 44892         Canada      Ontario
# 45092         Canada      Ontario
# ...

# %%
cases["sub_region_1"].head()
# Out:
# 35916    Ontario
# 35917    Ontario
# 35918    Ontario
# 35919    Ontario
# 35920    Ontario
# Name: sub_region_1, dtype: object
