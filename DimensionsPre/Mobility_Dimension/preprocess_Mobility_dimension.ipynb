# %%
import pandas as pd
import numpy as np

from datetime import datetime, timedelta

cases = pd.read_csv("../../Data/2020_CA_Region_Mobility_Report.csv")
# cases = cases[(cases["sub_region_1"]=="Ontario")]

# %%
Toronto = cases[cases["sub_region_2"]==("Toronto Division")]
Ottawa = cases[cases["sub_region_2"]==("Ottawa Division")]
frames = [Toronto, Ottawa]
Mobility_dimension = pd.concat(frames)
Mobility_dimension[["sub_region_2"]].drop_duplicates()
Mobility_dimension.insert(0, "surrogate_key",  np.arange(len(Mobility_dimension)))
Mobility_dimension.head()
# Out:
#        surrogate_key country_region_code country_region sub_region_1  \
# 53727              0                  CA         Canada      Ontario
# 53728              1                  CA         Canada      Ontario
# 53729              2                  CA         Canada      Ontario
# 53730              3                  CA         Canada      Ontario
# 53731              4                  CA         Canada      Ontario
#
#            sub_region_2  metro_area iso_3166_2_code  census_fips_code  \
# 53727  Toronto Division         NaN             NaN               NaN
# 53728  Toronto Division         NaN             NaN               NaN
# 53729  Toronto Division         NaN             NaN               NaN
# 53730  Toronto Division         NaN             NaN               NaN
# 53731  Toronto Division         NaN             NaN               NaN
#
#                           place_id        date  \
# 53727  ChIJ5b2RG4_L1IkRDtQ2gFEjLv4  2020-02-15
# 53728  ChIJ5b2RG4_L1IkRDtQ2gFEjLv4  2020-02-16
# 53729  ChIJ5b2RG4_L1IkRDtQ2gFEjLv4  2020-02-17
# 53730  ChIJ5b2RG4_L1IkRDtQ2gFEjLv4  2020-02-18
# 53731  ChIJ5b2RG4_L1IkRDtQ2gFEjLv4  2020-02-19
#
#        retail_and_recreation_percent_change_from_baseline  \
# 53727                                                0.0
# 53728                                               11.0
# 53729                                              -26.0
# 53730                                               -3.0
# 53731                                               -1.0
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# 53727                                                2.0
# 53728                                               10.0
# 53729                                              -45.0
# 53730                                               11.0
# 53731                                                3.0
#
#        parks_percent_change_from_baseline  \
# 53727                                15.0
# 53728                                35.0
# 53729                                49.0
# 53730                                -2.0
# 53731                                -3.0
#
#        transit_stations_percent_change_from_baseline  \
# 53727                                            1.0
# 53728                                            8.0
# 53729                                          -50.0
# 53730                                            1.0
# 53731                                           -2.0
#
#        workplaces_percent_change_from_baseline  \
# 53727                                      0.0
# 53728                                     -4.0
# 53729                                    -76.0
# 53730                                     -1.0
# 53731                                      0.0
#
#        residential_percent_change_from_baseline
# 53727                                      -1.0
# 53728                                      -3.0
# 53729                                      17.0
# 53730                                       0.0
# 53731                                       1.0

# %%
Mobility_dimension[["sub_region_2"]].drop_duplicates()
# Out:
#            sub_region_2
# 53727  Toronto Division
# 46980   Ottawa Division

# %%
cases
# Out:
#       country_region_code country_region sub_region_1 sub_region_2  \
# 0                      CA         Canada          NaN          NaN
# 1                      CA         Canada          NaN          NaN
# 2                      CA         Canada          NaN          NaN
# 3                      CA         Canada          NaN          NaN
# 4                      CA         Canada          NaN          NaN
# ...                   ...            ...          ...          ...
# 93223                  CA         Canada        Yukon          NaN
# 93224                  CA         Canada        Yukon          NaN
# 93225                  CA         Canada        Yukon          NaN
# 93226                  CA         Canada        Yukon          NaN
# 93227                  CA         Canada        Yukon          NaN
#
#        metro_area iso_3166_2_code  census_fips_code  \
# 0             NaN             NaN               NaN
# 1             NaN             NaN               NaN
# 2             NaN             NaN               NaN
# 3             NaN             NaN               NaN
# 4             NaN             NaN               NaN
# ...           ...             ...               ...
# 93223         NaN           CA-YT               NaN
# 93224         NaN           CA-YT               NaN
# 93225         NaN           CA-YT               NaN
# 93226         NaN           CA-YT               NaN
# 93227         NaN           CA-YT               NaN
#
#                           place_id        date  \
# 0      ChIJ2WrMN9MDDUsRpY9Doiq3aJk  2020-02-15
# 1      ChIJ2WrMN9MDDUsRpY9Doiq3aJk  2020-02-16
# 2      ChIJ2WrMN9MDDUsRpY9Doiq3aJk  2020-02-17
# 3      ChIJ2WrMN9MDDUsRpY9Doiq3aJk  2020-02-18
# 4      ChIJ2WrMN9MDDUsRpY9Doiq3aJk  2020-02-19
# ...                            ...         ...
# 93223  ChIJiYtStJiBF1ER6pbMYdWcFC4  2021-02-26
# 93224  ChIJiYtStJiBF1ER6pbMYdWcFC4  2021-02-27
# 93225  ChIJiYtStJiBF1ER6pbMYdWcFC4  2021-02-28
# 93226  ChIJiYtStJiBF1ER6pbMYdWcFC4  2021-03-01
# 93227  ChIJiYtStJiBF1ER6pbMYdWcFC4  2021-03-02
#
#        retail_and_recreation_percent_change_from_baseline  \
# 0                                                    4.0
# 1                                                   13.0
# 2                                                  -12.0
# 3                                                   -1.0
# 4                                                    1.0
# ...                                                  ...
# 93223                                              -34.0
# 93224                                              -24.0
# 93225                                              -38.0
# 93226                                              -29.0
# 93227                                              -29.0
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                    2.0
# 1                                                    8.0
# 2                                                  -15.0
# 3                                                    4.0
# 4                                                    1.0
# ...                                                  ...
# 93223                                                NaN
# 93224                                                NaN
# 93225                                                NaN
# 93226                                                NaN
# 93227                                                NaN
#
#        parks_percent_change_from_baseline  \
# 0                                    10.0
# 1                                    41.0
# 2                                    63.0
# 3                                     6.0
# 4                                     9.0
# ...                                   ...
# 93223                                 NaN
# 93224                                 NaN
# 93225                                 NaN
# 93226                                 NaN
# 93227                                 NaN
#
#        transit_stations_percent_change_from_baseline  \
# 0                                                3.0
# 1                                                4.0
# 2                                              -28.0
# 3                                               -1.0
# 4                                                0.0
# ...                                              ...
# 93223                                            NaN
# 93224                                            NaN
# 93225                                            NaN
# 93226                                            NaN
# 93227                                            NaN
#
#        workplaces_percent_change_from_baseline  \
# 0                                          1.0
# 1                                          0.0
# 2                                        -52.0
# 3                                         -1.0
# 4                                          0.0
# ...                                        ...
# 93223                                    -47.0
# 93224                                      NaN
# 93225                                      NaN
# 93226                                    -11.0
# 93227                                    -11.0
#
#        residential_percent_change_from_baseline
# 0                                           0.0
# 1                                          -2.0
# 2                                          11.0
# 3                                           1.0
# 4                                           0.0
# ...                                         ...
# 93223                                       NaN
# 93224                                       NaN
# 93225                                       NaN
# 93226                                       NaN
# 93227                                       NaN
#
# [93228 rows x 15 columns]
