# %%
import pandas as pd
import numpy as np

from datetime import datetime, timedelta

mobility = pd.read_csv("../../Data/2020_CA_Region_Mobility_Report.csv")
# cases = cases[(cases["sub_region_1"]=="Ontario")]
mobility = mobility.dropna(subset=["sub_region_2"])

# %%
mobility.isna().sum()
# Out:
# country_region_code                                       0
# country_region                                            0
# sub_region_1                                              0
# sub_region_2                                              0
# metro_area                                            88045
# iso_3166_2_code                                       88045
# census_fips_code                                      88045
# place_id                                                  0
# date                                                      0
# retail_and_recreation_percent_change_from_baseline    29834
# grocery_and_pharmacy_percent_change_from_baseline     27239
# parks_percent_change_from_baseline                    64588
# transit_stations_percent_change_from_baseline         59993
# workplaces_percent_change_from_baseline                2301
# residential_percent_change_from_baseline              37129
# dtype: int64

# %%
mobility = mobility.drop(columns=['metro_area', 'iso_3166_2_code', 'census_fips_code'])

# %%
durhanMobility = mobility[(mobility["sub_region_2"].map(lambda x: "durham" in x.lower()))]

haltonMobility = mobility[(mobility["sub_region_2"].map(lambda x: "halton" in x.lower()))]
# durhanMobility = mobility[(mobility["sub_region_2"].map(lambda x: "durham" in x.lower()))]
peelMobility = mobility[(mobility["sub_region_2"].map(lambda x: "peel" in x.lower()))]
yorkMobility = mobility[(mobility["sub_region_2"].map(lambda x: "municipality of york" in x.lower()))]
ottawaMobility = mobility[(mobility["sub_region_2"].map(lambda x: "ottawa" in x.lower()))]
torontoMobility = mobility[(mobility["sub_region_2"].map(lambda x: "toronto" in x.lower()))]
frames = [durhanMobility, haltonMobility, peelMobility, yorkMobility, ottawaMobility, torontoMobility]
mobility = pd.concat(frames)
Mobility_dimension = mobility.fillna({'Outbreak_Related':'Unknown'})

# %%
mobility["sub_region_2"].drop_duplicates()
# Out:
# 49681    Regional Municipality of Durham
# 50063    Regional Municipality of Halton
# 50827      Regional Municipality of Peel
# 51209      Regional Municipality of York
# 46980                    Ottawa Division
# 53727                   Toronto Division
# Name: sub_region_2, dtype: object

# %%
durhanMobility
# Out:
#       country_region_code country_region sub_region_1  \
# 49681                  CA         Canada      Ontario
# 49682                  CA         Canada      Ontario
# 49683                  CA         Canada      Ontario
# 49684                  CA         Canada      Ontario
# 49685                  CA         Canada      Ontario
# ...                   ...            ...          ...
# 50058                  CA         Canada      Ontario
# 50059                  CA         Canada      Ontario
# 50060                  CA         Canada      Ontario
# 50061                  CA         Canada      Ontario
# 50062                  CA         Canada      Ontario
#
#                           sub_region_2                     place_id  \
# 49681  Regional Municipality of Durham  ChIJNWdhlINO1YkR3unhOZ62X88
# 49682  Regional Municipality of Durham  ChIJNWdhlINO1YkR3unhOZ62X88
# 49683  Regional Municipality of Durham  ChIJNWdhlINO1YkR3unhOZ62X88
# ...

# %%
mobility["sub_region_2"].drop_duplicates()
# Out:
# 49681    Regional Municipality of Durham
# 50063    Regional Municipality of Halton
# 50827      Regional Municipality of Peel
# 51209      Regional Municipality of York
# 46980                    Ottawa Division
# 53727                   Toronto Division
# Name: sub_region_2, dtype: object

# %%
# Toronto = mobility[mobility["sub_region_2"]==("Toronto Division")]
# Ottawa = mobility[mobility["sub_region_2"]==("Ottawa Division")]
# frames = [Toronto, Ottawa]
# Mobility_dimension = pd.concat(frames)
# # Mobility_dimension[["sub_region_2"]].drop_duplicates()
# Mobility_dimension["sub_region_2"] = Mobility_dimension["sub_region_2"].map(lambda x: x.split()[0])
Mobility_dimension.insert(0, "surrogate_key",  np.arange(len(Mobility_dimension)))
Mobility_dimension.head()
# Out:
#        surrogate_key country_region_code country_region sub_region_1  \
# 49681              0                  CA         Canada      Ontario
# 49682              1                  CA         Canada      Ontario
# 49683              2                  CA         Canada      Ontario
# 49684              3                  CA         Canada      Ontario
# 49685              4                  CA         Canada      Ontario
#
#                           sub_region_2                     place_id  \
# 49681  Regional Municipality of Durham  ChIJNWdhlINO1YkR3unhOZ62X88
# 49682  Regional Municipality of Durham  ChIJNWdhlINO1YkR3unhOZ62X88
# 49683  Regional Municipality of Durham  ChIJNWdhlINO1YkR3unhOZ62X88
# 49684  Regional Municipality of Durham  ChIJNWdhlINO1YkR3unhOZ62X88
# 49685  Regional Municipality of Durham  ChIJNWdhlINO1YkR3unhOZ62X88
#
#              date  retail_and_recreation_percent_change_from_baseline  \
# ...

# %%
Mobility_dimension.to_csv("Mobility_dimension.csv",index=False)

# %%
Mobility_dimension.isna().sum()
# Out:
# surrogate_key                                          0
# country_region_code                                    0
# country_region                                         0
# sub_region_1                                           0
# sub_region_2                                           0
# place_id                                               0
# date                                                   0
# retail_and_recreation_percent_change_from_baseline     0
# grocery_and_pharmacy_percent_change_from_baseline      0
# parks_percent_change_from_baseline                    80
# transit_stations_percent_change_from_baseline          3
# workplaces_percent_change_from_baseline                0
# residential_percent_change_from_baseline               0
# dtype: int64

# %%
Mobility_dimension.shape

# %%
Mobility_dimension["sub_region_2"].drop_duplicates()
